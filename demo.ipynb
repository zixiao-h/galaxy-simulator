# %%
import numpy as np
import numba as nb
from model import system

# %%
galaxy8 = system()
mass0 = galaxy8.add_mass(np.array([0,0]), np.array([0,0]), 1)
galaxy8.add_ring(2, 120, mass0)
galaxy8.add_ring(2.2, 150, mass0)
galaxy8.add_ring(2.4, 180, mass0)
galaxy8.add_ring(2.6, 210, mass0)
galaxy8.add_ring(2.8, 240, mass0)
galaxy8.add_ring(3.0, 270, mass0)
galaxy8.add_ring(3.2, 300, mass0)
galaxy8.add_ring(3.4, 330, mass0)
galaxy8.add_ring(3.6, 360, mass0)

mass1 = galaxy8.add_mass(np.array([0,11]), np.array([np.sqrt(0.3),-0.1]), 1) # 10, sqrt(0.2) for parabolic
galaxy8.add_ring(2, 120, mass1)
galaxy8.add_ring(2.2, 150, mass1)
galaxy8.add_ring(2.4, 180, mass1)
galaxy8.add_ring(2.6, 210, mass1)
galaxy8.add_ring(2.8, 240, mass1)
galaxy8.add_ring(3.0, 270, mass1)
galaxy8.add_ring(3.2, 300, mass1)
galaxy8.add_ring(3.4, 330, mass1)
galaxy8.add_ring(3.6, 360, mass1)

galaxy8.plot(30)
galaxy8.evolve(1,0.5)

# %%
galaxy8.evolve(1500,0.2)

# %%
galaxy8.animate('m111-1500.2.gif', 10, xylims=[(-50,100),(-80,80)])
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
